# %%
#chi square test practice
import seaborn as sns
import pandas as pd

# %%
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data=pd.crosstab(df["smoker"],df["sex"])
data
# Out:
# sex     Male  Female
# smoker
# Yes       60      33
# No        97      54

# %%
data=pd.crosstab(df["day"],df["size"])
data
# Out:
# size  1   2   3   4  5  6
# day
# Thur  1  48   4   5  1  3
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1

# %%
obs_value=data.values
obs_value
# Out:
# array([[ 1, 48,  4,  5,  1,  3],
#        [ 1, 16,  1,  1,  0,  0],
#        [ 2, 53, 18, 13,  1,  0],
#        [ 0, 39, 15, 18,  3,  1]])

# %%
from scipy import stats

# %%
value=stats.chi2_contingency(data)
value
# Out:
# Chi2ContingencyResult(statistic=29.632849936919712, pvalue=0.013316478351860587, dof=15, expected_freq=array([[ 1.01639344, 39.63934426,  9.6557377 ,  9.40163934,  1.2704918 ,
#          1.01639344],
#        [ 0.31147541, 12.14754098,  2.95901639,  2.88114754,  0.38934426,
#          0.31147541],
#        [ 1.42622951, 55.62295082, 13.54918033, 13.19262295,  1.78278689,
#          1.42622951],
#        [ 1.24590164, 48.59016393, 11.83606557, 11.52459016,  1.55737705,
#          1.24590164]]))

# %%
exp_value=value[3]
exp_value
# Out:
# array([[ 1.01639344, 39.63934426,  9.6557377 ,  9.40163934,  1.2704918 ,
#          1.01639344],
#        [ 0.31147541, 12.14754098,  2.95901639,  2.88114754,  0.38934426,
#          0.31147541],
#        [ 1.42622951, 55.62295082, 13.54918033, 13.19262295,  1.78278689,
#          1.42622951],
#        [ 1.24590164, 48.59016393, 11.83606557, 11.52459016,  1.55737705,
#          1.24590164]])

# %%
chi_square=sum(sum([((obs_value-exp_value)**2)/exp_value for obs_value,exp_value in zip(obs_value,exp_value)]))
chi_square
# Out:
# 29.632849936919712

# %%
#level of significance
# p=0.075
# p+q=1   ===>q=1-0.075
crt_value=stats.chi2.ppf(q=.925,df=15)
crt_value
# Out:
# 23.45216705276617

# %%
if chi_square >= crt_value:
  print("ho is rejected,ha is accepted,there is a relationship between(size & day)")
else:
  print("ho is accepted,ha is rejected,there is no relationship between(size & day)")
# Out:
# ho is rejected,ha is accepted,there is a relationship between(size & day)

# %%
p_value=1-stats.chi2.cdf(x=chi_square,df=15)
p_value
# Out:
# 0.013316478351860561

# %%
if p_value < 0.075:
  print("ho is rejected,ha is accepted,there is a relationship between(size & day)")
else:
  print("ho is accepted,ha is rejected,there is no relationship between(size & day)")
# Out:
# ho is rejected,ha is accepted,there is a relationship between(size & day)
