# %% [markdown]
# <a href="https://colab.research.google.com/github/NANDHAKUMAR-PERIYANNAN/DailyPractice/blob/main/PandasQuery1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Car_sales.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
df.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
df.iloc[4,5]
# Out:
# 23.99

# %%
#reverse indexing
df.iloc[110:49:-3,2:8]
# Out:
#      Sales_in_thousands  __year_resale_value Vehicle_type  Price_in_thousands  \
# 110              80.255                  NaN    Passenger              18.270
# 107              65.005                  NaN          Car              17.890
# 104              27.308               15.380          Car              26.399
# 101              42.643                8.450    Passenger              13.499
# 98               11.592                  NaN    Passenger              41.600
# ..                  ...                  ...          ...                 ...
# 62               41.184                5.860    Passenger               9.699
# 59               73.203               17.710          Car              20.550
# 56              540.561               15.075          Car              26.935
# 53              155.787               13.175          Car              21.410
# 50              175.670                  NaN    Passenger              12.315
#
#      Engine_size  Horsepower
# ...

# %%
#value indexing
df.iloc[[120,34,56],[3,7,8]]
# Out:
#      __year_resale_value  Horsepower  Wheelbase
# 120               17.805       200.0      101.1
# 34                   NaN       253.0      113.0
# 56                15.075       220.0      138.5

# %%
#column name based indexing
df.loc[2:10,["__year_resale_value","Horsepower"]]
# Out:
#     __year_resale_value  Horsepower
# 2                18.225       225.0
# 3                29.725       210.0
# 4                22.255       150.0
# 5                23.555       200.0
# 6                39.000       310.0
# 7                   NaN       170.0
# 8                28.675       193.0
# 9                36.125       193.0
# 10               12.475       175.0

# %%
df[df.Manufacturer=='Toyota']
# Out:
#     Manufacturer         Model  Sales_in_thousands  __year_resale_value  \
# 136       Toyota       Corolla             142.535               10.025
# 137       Toyota         Camry             247.994               13.245
# 138       Toyota        Avalon              63.849               18.140
# 139       Toyota        Celica              33.269               15.445
# 140       Toyota        Tacoma              84.087                9.575
# 141       Toyota        Sienna              65.119                  NaN
# 142       Toyota          RAV4              25.106               13.325
# 143       Toyota       4Runner              68.411               19.425
# 144       Toyota  Land Cruiser               9.835               34.080
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 136    Passenger              13.108          1.8       120.0       97.0
# 137    Passenger              17.518          2.2       133.0      105.2
# ...

# %%
#Query to count by selection on case
df["__year_resale_value"][(df.Vehicle_type=="Car")& df.Manufacturer=="Toyota"].count()
# Out:
# 0

# %%
df[df.Horsepower==150].count()
# Out:
# Manufacturer           9
# Model                  9
# Sales_in_thousands     9
# __year_resale_value    8
# Vehicle_type           9
#                       ..
# Curb_weight            9
# Fuel_capacity          9
# Fuel_efficiency        9
# Latest_Launch          9
# Power_perf_factor      9
# Length: 16, dtype: int64

# %%
df.query("Manufacturer=='Toyota'")
# Out:
#     Manufacturer         Model  Sales_in_thousands  __year_resale_value  \
# 136       Toyota       Corolla             142.535               10.025
# 137       Toyota         Camry             247.994               13.245
# 138       Toyota        Avalon              63.849               18.140
# 139       Toyota        Celica              33.269               15.445
# 140       Toyota        Tacoma              84.087                9.575
# 141       Toyota        Sienna              65.119                  NaN
# 142       Toyota          RAV4              25.106               13.325
# 143       Toyota       4Runner              68.411               19.425
# 144       Toyota  Land Cruiser               9.835               34.080
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 136    Passenger              13.108          1.8       120.0       97.0
# 137    Passenger              17.518          2.2       133.0      105.2
# ...

# %%
df.Manufacturer.value_counts()
# Out:
# Dodge         11
# Ford          11
# Toyota         9
# Chevrolet      9
# Mercedes-B     9
#               ..
# Lincoln        3
# Saab           2
# Subaru         2
# Jaguar         1
# Infiniti       1
# Name: Manufacturer, Length: 30, dtype: int64

# %%
#view all column or dataframe
pd.set_option("display.max_rows",10)
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df.nunique()
# Out:
# Manufacturer            30
# Model                  156
# Sales_in_thousands     157
# __year_resale_value    117
# Vehicle_type             2
#                       ...
# Curb_weight            147
# Fuel_capacity           55
# Fuel_efficiency         20
# Latest_Launch          130
# Power_perf_factor      154
# Length: 16, dtype: int64

# %%
df.groupby("Manufacturer")['Sales_in_thousands'].mean()
# Out:
# Manufacturer
# Acura         19.751250
# Audi          13.519000
# BMW           15.501667
# Buick         60.504750
# Cadillac      22.435600
#                 ...
# Saturn        33.770000
# Subaru        40.067500
# Toyota        82.245000
# Volkswagen    34.868667
# Volvo         12.623333
# Name: Sales_in_thousands, Length: 30, dtype: float64

# %%
df.groupby("Manufacturer")['Sales_in_thousands'].sum()
# Out:
# Manufacturer
# Acura          79.005
# Audi           40.557
# BMW            46.505
# Buick         242.019
# Cadillac      112.178
#                ...
# Saturn        168.850
# Subaru         80.135
# Toyota        740.205
# Volkswagen    209.212
# Volvo          75.740
# Name: Sales_in_thousands, Length: 30, dtype: float64

# %%
#sort by values in ascending order
df.sort_values(by="Sales_in_thousands",ascending=True)
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 83    Mitsubishi         3000GT               0.110               20.940
# 39         Dodge          Viper               0.916               58.470
# 99    Mercedes-B          CL500               0.954                  NaN
# 108   Oldsmobile        Cutlass               1.112               11.240
# 125      Porsche  Carrera Coupe               1.280               60.625
# ..           ...            ...                 ...                  ...
# 58         Honda         Accord             230.902               13.210
# 49          Ford         Taurus             245.815               10.055
# 137       Toyota          Camry             247.994               13.245
# 52          Ford       Explorer             276.747               16.640
# 56          Ford       F-Series             540.561               15.075
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
#sort by values[Multiple column] in ascending order
df.sort_values(by=["Sales_in_thousands","Manufacturer","Vehicle_type"],ascending=[True,True,True])
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 83    Mitsubishi         3000GT               0.110               20.940
# 39         Dodge          Viper               0.916               58.470
# 99    Mercedes-B          CL500               0.954                  NaN
# 108   Oldsmobile        Cutlass               1.112               11.240
# 125      Porsche  Carrera Coupe               1.280               60.625
# ..           ...            ...                 ...                  ...
# 58         Honda         Accord             230.902               13.210
# 49          Ford         Taurus             245.815               10.055
# 137       Toyota          Camry             247.994               13.245
# 52          Ford       Explorer             276.747               16.640
# 56          Ford       F-Series             540.561               15.075
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type            object
#                         ...
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Latest_Launch           object
# Power_perf_factor      float64
# Length: 16, dtype: object

# %%
# Volkswagen

col=input("Enter the Manufacturer Name :")

x=df["__year_resale_value"][df["Manufacturer"]==col].values

for i in x:
  print(i)
# Out:
# Enter the Manufacturer Name :Audi
# 22.255
# 23.555
# 39.0

# %%
df.query("Manufacturer=='Audi'")
# Out:
#   Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 4         Audi    A4              20.397               22.255    Passenger
# 5         Audi    A6              18.780               23.555    Passenger
# 6         Audi    A8               1.380               39.000    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 4               23.99          1.8       150.0      102.6   68.2   178.0
# 5               33.95          2.8       200.0      108.7   76.1   192.0
# 6               62.00          4.2       310.0      113.0   74.0   198.2
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 4        2.998           16.4             27.0     10/8/2011
# 5        3.561           18.5             22.0      8/9/2011
# 6        3.902           23.7             21.0     2/27/2012
#
#    Power_perf_factor
# 4          62.777639
# 5          84.565105
# 6         134.656858

# %%
df.isnull().count()
# Out:
# Manufacturer           157
# Model                  157
# Sales_in_thousands     157
# __year_resale_value    157
# Vehicle_type           157
#                       ...
# Curb_weight            157
# Fuel_capacity          157
# Fuel_efficiency        157
# Latest_Launch          157
# Power_perf_factor      157
# Length: 16, dtype: int64

# %%
df.fillna(123)
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545              123.000
# 153        Volvo      S70              15.245              123.000
# 154        Volvo      V70              17.531              123.000
# 155        Volvo      C70               3.493              123.000
# 156        Volvo      S80              18.969              123.000
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df["__year_resale_value"].fillna(value=df.__year_resale_value.mean(),inplace=True)
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919            16.360000
# 1          Acura       TL              39.384            19.875000
# 2          Acura       CL              14.114            18.225000
# 3          Acura       RL               8.588            29.725000
# 4           Audi       A4              20.397            22.255000
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545            18.072975
# 153        Volvo      S70              15.245            18.072975
# 154        Volvo      V70              17.531            18.072975
# 155        Volvo      C70               3.493            18.072975
# 156        Volvo      S80              18.969            18.072975
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df["Manufacturer"].fillna(value="Nandhi",inplace=True)
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919            16.360000
# 1          Acura       TL              39.384            19.875000
# 2          Acura       CL              14.114            18.225000
# 3          Acura       RL               8.588            29.725000
# 4           Audi       A4              20.397            22.255000
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545            18.072975
# 153        Volvo      S70              15.245            18.072975
# 154        Volvo      V70              17.531            18.072975
# 155        Volvo      C70               3.493            18.072975
# 156        Volvo      S80              18.969            18.072975
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df["Manufacturer"]=='Nandhi'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 152    False
# 153    False
# 154    False
# 155    False
# 156    False
# Name: Manufacturer, Length: 157, dtype: bool
